# %% [markdown]
# <a href="https://colab.research.google.com/github/Varsha-A11/Fish_weight_prediction/blob/main/Fish_weight.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Fish weight perdiction
#
#  We have a dataset containing different fish species along with their physical characteristics, such as vertical length, diagonal length, height, and width. Our goal is to predict the weight of a fish based on these characteristics. To achieve this, we will use the Linear Regression method to analyze how the fish’s weight is related to its physical features.

# %%
import pandas as pd

# %%
fish = pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Fish.csv')

# %%
fish.head()
# Out:
#    Category Species  Weight   Height   Width  Length1  Length2  Length3
# 0         1   Bream   242.0  11.5200  4.0200     23.2     25.4     30.0
# 1         1   Bream   290.0  12.4800  4.3056     24.0     26.3     31.2
# 2         1   Bream   340.0  12.3778  4.6961     23.9     26.5     31.1
# 3         1   Bream   363.0  12.7300  4.4555     26.3     29.0     33.5
# 4         1   Bream   430.0  12.4440  5.1340     26.5     29.0     34.0

# %%
fish.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  159 non-null    int64
#  1   Species   159 non-null    object
#  2   Weight    159 non-null    float64
#  3   Height    159 non-null    float64
#  4   Width     159 non-null    float64
#  5   Length1   159 non-null    float64
#  6   Length2   159 non-null    float64
#  7   Length3   159 non-null    float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 10.1+ KB

# %%
fish.describe()
# Out:
#          Category       Weight      Height       Width     Length1  \
# count  159.000000   159.000000  159.000000  159.000000  159.000000
# mean     3.264151   398.326415    8.970994    4.417486   26.247170
# std      1.704249   357.978317    4.286208    1.685804    9.996441
# min      1.000000     0.000000    1.728400    1.047600    7.500000
# 25%      2.000000   120.000000    5.944800    3.385650   19.050000
# 50%      3.000000   273.000000    7.786000    4.248500   25.200000
# 75%      4.500000   650.000000   12.365900    5.584500   32.700000
# max      7.000000  1650.000000   18.957000    8.142000   59.000000
#
#           Length2     Length3
# count  159.000000  159.000000
# mean    28.415723   31.227044
# std     10.716328   11.610246
# min      8.400000    8.800000
# 25%     21.000000   23.150000
# 50%     27.300000   29.400000
# 75%     35.500000   39.650000
# max     63.400000   68.000000

# %%
fish.columns
# Out:
# Index(['Category', 'Species', 'Weight', 'Height', 'Width', 'Length1',
#        'Length2', 'Length3'],
#       dtype='object')

# %%
X = fish[['Category','Height', 'Width', 'Length1','Length2', 'Length3']]
y = fish['Weight']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.7, random_state=59)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((111, 6), (48, 6), (111,), (48,))

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# np.float64(-613.7221727056177)

# %%
model.coef_
# Out:
# array([ 24.87903112,  48.02165371,   4.90560424,  59.4021415 ,
#         20.17476406, -53.23795954])

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([ 2.48652744e+02,  2.18053427e+02,  6.67782039e+02,  5.44899206e+02,
#         1.07362487e+03,  1.51838661e+02, -1.40524258e+02, -1.64427196e+02,
#         9.25381846e+02,  6.07303814e+02,  1.10671822e+03,  2.34270255e+02,
#         6.46601801e+02, -3.65133893e+00, -1.15070480e+02,  3.45853583e+02,
#         6.17702593e+02,  5.83284387e+02,  2.13021251e+02,  6.16854362e+02,
#        -9.44570001e-01,  2.77516742e+02,  6.96096517e+02,  1.36438178e+02,
#        -1.41358980e+02,  7.84793866e+02, -2.00626183e+02,  8.23779655e+02,
#         6.92401868e+02,  1.52415070e+02,  7.76103650e+02,  5.77602001e+02,
#        -5.29601053e+01, -1.02588219e+02,  8.98905958e+02,  1.53872698e+02,
#        -5.45042125e+01,  6.35500986e+02,  7.85392000e+02,  7.12612909e+02,
#         3.51404887e+02,  7.59951511e+01,  6.79622435e+01,  1.20532313e+03,
#         8.01908427e+02,  8.51764059e+01,  1.48503168e+02,  1.06174252e+02])

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 109.70093040815236

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8771911318843478
